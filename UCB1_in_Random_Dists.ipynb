# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import os
LIB_PATH = os.getcwd()

import sys
sys.path.append(LIB_PATH)

# %%
from environments import RandomDistributionEnvironmentFactory
from constants import BANDIT_FEEDBACK
from models import Experiment
from algs import UCB1

dist = (np.random.multivariate_normal, [0, 0.5, 0.7], np.diag([0.1, 0.1, 0.1]))
factory = RandomDistributionEnvironmentFactory(BANDIT_FEEDBACK, 1000, *dist)
experiment = Experiment(50, factory)

algorithm = UCB1()
results = experiment.run(algorithm, verbose=True)
# Out:
# Running <algs.UCB1 object at 0x117ea5208> on <environments.RandomDistributionEnvironmentFactory object at 0x117ea51d0>
# ..................................................
# Completed <algs.UCB1 object at 0x117ea5208> on <environments.RandomDistributionEnvironmentFactory object at 0x117ea51d0>

# %%
from constants import BANDIT_FEEDBACK
from metrics import average_reward 
import pandas as pd

alg_avg = average_reward(results, feedback=BANDIT_FEEDBACK)

pd.DataFrame({'UCB1': alg_avg}).plot()
